# %% [markdown]
# ### ingest data

# %%
import pandas as pd

# %%
data = pd.read_parquet('../data/data.parquet', engine='pyarrow')
data.head(3)
# Out:
#    id  topic                                     question_title  \
# 0   0      4  why doesn't an optical mouse work on a glass t...
# 1   1      5       What is the best off-road motorcycle trail ?
# 2   2      2             What is Trans Fat? How to reduce that?
#
#                                     question_content  \
# 0                          or even on some surfaces?
# 1                  long-distance trail throughout CA
# 2  I heard that tras fat is bad for the body.  Wh...
#
#                                          best_answer
# 0  Optical mice use an LED and a camera to rapidl...
# 1  i hear that the mojave road is amazing!<br />\...
# 2  Trans fats occur in manufactured foods during ...

# %%
data_copy = data.copy()

# %% [markdown]
# ### transform data (copy)

# %%
topic_labels = {
    0: "Society & Culture",
    1: "Science & Mathematics",
    2: "Health",
    3: "Education & Reference",
    4: "Computers & Internet",
    5: "Sports",
    6: "Business & Finance",
    7: "Entertainment & Music",
    8: "Family & Relationships",
    9: "Politics & Government"
}

data_copy["topic_name"] = data_copy["topic"].map(topic_labels)
data_copy.head(3)
# Out:
#    id  topic                                     question_title  \
# 0   0      4  why doesn't an optical mouse work on a glass t...
# 1   1      5       What is the best off-road motorcycle trail ?
# 2   2      2             What is Trans Fat? How to reduce that?
#
#                                     question_content  \
# 0                          or even on some surfaces?
# 1                  long-distance trail throughout CA
# 2  I heard that tras fat is bad for the body.  Wh...
#
#                                          best_answer            topic_name
# 0  Optical mice use an LED and a camera to rapidl...  Computers & Internet
# 1  i hear that the mojave road is amazing!<br />\...                Sports
# 2  Trans fats occur in manufactured foods during ...                Health

# %%
import re


def preprocessor(text):
    text = (re.sub(r'[\W]+', ' ', text.lower()))
    return text

# %%
data_copy["question_title"] = data_copy["question_title"].apply(preprocessor)

# %%
data_copy_processed = data_copy.copy()
data_copy_processed.to_csv("../data/data_preprocessed.parquet", index=False)
